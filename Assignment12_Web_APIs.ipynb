# %% [markdown]
# <div align='center'> <b> <span style='color:green'> <h1> ASSIGNMENT WEEK 13 - PREDICTIVE ANALYSIS </h1> </span> </b> </div>

# %% [markdown]
# The New York Times web site provides a rich set of [APIs](http://developer.nytimes.com/docs).
#
# For this assignment, you’ll need to start by signing up for an API [key](http://developer.nytimes.com/signup). Your task is to choose one of the New York Times APIs, construct an interface in [Python](https://www.python.org/) to read in the [JSON](https://www.json.org/) data, and transform it into a [pandas](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) DataFrame.

# %% [markdown]
# <h><b> We begin by importing the necessary libraries. </b></h>

# %%
import pandas as pd
import json, requests
from pandas.io.json import json_normalize

# %% [markdown]
# <h><b> We proceed by requesting the API data. </b></h>

# %%
#The data is obtained from - http://developer.nytimes.com/movie_reviews_v2.json#/Console/GET/reviews/search.json
#Once signed up NYT provides an API Key: '9e5f80aa2fa343afa13d9389c62c852b'

api_key = '9e5f80aa2fa343afa13d9389c62c852b'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
string = url + '&api-key=' + api_key

repos = json.loads(requests.get(string).text) #getting data to display
repos
# Out:
# {'copyright': 'Copyright (c) 2017 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'byline': 'A. O. SCOTT',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:38',
#    'display_title': 'Mudbound',
#    'headline': 'Review: ‘Mudbound’ Is a Racial Epic Tuned to Black Lives, and White Guilt',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Mudbound',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/mudbound-review-dee-rees.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17mudbound-1/merlin_129717470_87efdb0c-c269-41f8-b64a-b5e943287248-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'Dee Rees’s new film illuminates the daily cruelties in post-World War II Mississippi.'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 15:56:03',
#    'display_title': 'Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Clifton',
#    'headline': 'Review: ‘Jim & Andy,’ When Carrey Became Kaufman',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Clifton',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/review-jim-and-andy-jim-carrey.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17jimandandy-web1/17jimandandy-web1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'In his documentary about Jim Carrey, Andy Kaufman and the making of “Man on the Moon,” the director Chris Smith finds multiple realities and laughs.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:37',
#    'display_title': 'The Breadwinner',
#    'headline': 'Review: In ‘The Breadwinner,’ a Girl Bravely Provides for Her Family',
#    'link': {'suggested_link_text': 'Read the New York Times Review of The Breadwinner',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/the-breadwinner-review.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17breadwinner/17breadwinner-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'The children in this animated film based on a novel by Deborah Ellis navigate life under the Taliban.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:35',
#    'display_title': 'Wonder',
#    'headline': 'Review: In ‘Wonder,’ a Not-So-Ordinary Boy Makes His Way',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Wonder',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/wonder-review-jacob-tremblay-julia-roberts-owen-wilson.html'},
#    'mpaa_rating': 'PG',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/13/movies/Wonder1/Wonder1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'Auggie, the little boy in this smart and warmhearted family film, is inspirational in his differences.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 12:04:04',
#    'display_title': 'Sweet Virginia',
#    'headline': 'Review: A Small-Town Murder Ignites ‘Sweet Virginia’',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Sweet Virginia',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/sweet-virginia-review.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/movies/SWEETVIRGINIA1/SWEETVIRGINIA1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-16',
#    'summary_short': 'Set in a remote Alaskan valley, the film is a quiet knife-twister in which atmosphere and performance are everything.'},
#   {'byline': 'TEO BUGBEE',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 12:04:02',
#    'display_title': 'Big Sonia',
#    'headline': 'Review: ‘Big Sonia’ Honors a Holocaust Survivor',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Big Sonia',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/review-big-sonia-review-holocaust-survivor.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/movies/bigsonia1/bigsonia1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-16',
#    'summary_short': 'Sonia Warshawski, the owner of a tailor shop in a deserted mall, and also a survivor of the Holocaust, is a powerful documentary subject.'},
#   {'byline': 'A. O. SCOTT',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 12:04:06',
#    'display_title': 'On the Beach at Night Alone',
#    'headline': 'Review: ‘On the Beach at Night Alone’ Zooms in on a Love Affair',
#    'link': {'suggested_link_text': 'Read the New York Times Review of On the Beach at Night Alone',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/on-the-beach-at-night-alone-review-hong-sang-soo.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17onthebeach/17onthebeach-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-16',
#    'summary_short': 'Kim Min-hee stars in a new film from the prolific South Korean director Hong Sang-soo. The movie has been seen as based partly on their affair.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 12:04:06',
#    'display_title': 'Porto',
#    'headline': 'Review: In ‘Porto,’ a Night of Bliss and Heartbreak',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Porto',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/porto-review-anton-yelchin.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17porto/17porto-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-16',
#    'summary_short': 'In one of the last film roles before his death, Anton Yelchin stars in this first narrative feature from Gabe Klinger.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 12:04:03',
#    'display_title': 'Wet Woman in the Wind',
#    'headline': 'Review: ‘Wet Woman in the Wind’ Is a Queasy Sex Romp',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Wet Woman in the Wind',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/wet-woman-in-the-wind-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/movies/17wetwoman/merlin_129774299_7c12221e-cc83-4dc4-869d-71d99eb6fb4e-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'Let’s make no bones about it: This film, part of a project to reboot a Japanese soft-core genre, is designed to appeal to male prurient interest.'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 17:44:34',
#    'display_title': 'Roman J. Israel, Esq.',
#    'headline': 'Review: In ‘Roman J. Israel, Esq.,’ Denzel Washington as a Lawyer Out of His Element',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Roman J. Israel, Esq.',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/roman-j-israel-review-denzel-washington.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17ROMAN/17ROMAN-mediumThreeByTwo210-v2.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-22',
#    'publication_date': '2017-11-16',
#    'summary_short': 'Dan Gilroy’s new film about a socially awkward jurist misfires when it appoints him as a sort of angelic figure.'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 17:44:34',
#    'display_title': 'Cook Off!',
#    'headline': 'Review: ‘Cook Off!’ Gives Chefs the ‘Best in Show’ Treatment',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Cook Off!',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/16/movies/review-cook-off-melissa-mccarthy.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/arts/17cookoff1/17cookoff1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-16',
#    'summary_short': 'This mockumentary about a cooking competition features Melissa McCarthy but is being released 10 years after it was first shown at a comedy festival.'},
#   {'byline': 'A. O. SCOTT',
#    'critics_pick': 1,
#    'date_updated': '2017-11-15 20:38:02',
#    'display_title': 'A Fantastic Woman',
#    'headline': 'Review: ‘A Fantastic Woman’ Lives Up to Its Title, in More Ways Than One',
#    'link': {'suggested_link_text': 'Read the New York Times Review of A Fantastic Woman',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/a-fantastic-woman-review.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17fantastic1/17fantastic1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2018-02-02',
#    'publication_date': '2017-11-15',
#    'summary_short': 'Facing a lover’s death and a society’s intolerance, in a film by Sebastián Lelio.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:36:03',
#    'display_title': 'Rebels on Pointe',
#    'headline': 'Review: ‘Rebels on Pointe,’ and in Tutus',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Rebels on Pointe',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/rebels-on-pointe-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/arts/17REBELS1/17REBELS1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-09-15',
#    'publication_date': '2017-11-15',
#    'summary_short': 'The Ballets Russes de Monte Carlo meld technique with comedy, and tour more than two-thirds of the years'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 17:44:32',
#    'display_title': 'Justice League',
#    'headline': 'Review: ‘Justice League,’ Better Than the Last One!',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Justice League',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/justice-league-review-wonder-woman-batman-dc-comics.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17justiceleague-web1/17justiceleague-web1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-15',
#    'summary_short': 'In this superhero jamboree, the Flash, Aquaman and Cyborg sign on with the DC Comics team leaders Batman and Wonder Woman. (Psst … where’s Superman?)'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 17:44:32',
#    'display_title': 'Song of Granite',
#    'headline': 'Review: In ‘Song of Granite,’ Fragments of an Irish Folk Singer’s Life',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Song of Granite',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/14/movies/song-of-granite-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/arts/15SONGOFGRANITE/15SONGOFGRANITE-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-15',
#    'publication_date': '2017-11-14',
#    'summary_short': 'This biography of the singer Joe Heaney seems uncertain of what made him tick.'},
#   {'byline': 'MONICA CASTILLO',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:30',
#    'display_title': 'Santa & Andrés',
#    'headline': 'Review: ‘Santa & Andrés’ Chooses Friendship Over Politics',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Santa & Andrés',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/santa-and-andres-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10SANTAANDRES/santa1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'A loyal Communist worker and a dissident gay writer become unlikely friends in this touching Cuban drama.'},
#   {'byline': 'ANDY WEBSTER',
#    'critics_pick': 1,
#    'date_updated': '2017-11-09 12:04:03',
#    'display_title': 'I Remember You',
#    'headline': 'Review: ‘I Remember You’ Is a Piercing Horror Film From Iceland',
#    'link': {'suggested_link_text': 'Read the New York Times Review of I Remember You',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/i-remember-you-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/movies/10irememberyou/10irememberyou-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'The director Oskar Thor Axelsson prefers mood and compelling human conflict over copious gore to deliver chills. The result is effective.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:28',
#    'display_title': 'Bitch',
#    'headline': 'Review: In ‘Bitch,’ a Desperate Housewife Finds Her Bark',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Bitch',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/bitch-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/08/arts/bitch1/bitch1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Jason Ritter plays a husband whose wife goes to the dogs in this feminist horror-comedy.'},
#   {'byline': 'TEO BUGBEE',
#    'critics_pick': 1,
#    'date_updated': '2017-11-16 17:44:27',
#    'display_title': 'Window Horses: The Poetic Persian Epiphany of Rosie Ming',
#    'headline': 'Review: ‘Window Horses’ Animates a Young Poet’s Self-Discovery',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Window Horses: The Poetic Persian Epiphany of Rosie Ming',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/window-horses-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10windowhorses/windowhorses1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Ann Marie Fleming’s film explores the passions of a sheltered poet who travels to Shiraz, Iran, for a poetry festival.'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-16 17:44:31',
#    'display_title': "Daddy's Home 2",
#    'headline': 'Review: In ‘Daddy’s Home 2,’ Father Doesn’t Know Best',
#    'link': {'suggested_link_text': "Read the New York Times Review of Daddy's Home 2",
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/review-in-daddys-home-2-mel-gibson-will-ferrell-mark-wahlberg.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10daddyshome1/10daddyshome1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Mel Gibson gets off lightly as a crass paterfamilias in this comedy sequel to the hit starring Will Ferrell and Mark Wahlberg.'}],
#  'status': 'OK'}

# %% [markdown]
# <h><b> For easier viewing we can proceed by normalizing the data. </b></h>

# %%
normal = json_normalize(repos['results'])
normal
# Out:
#                  byline  critics_pick         date_updated  \
# 0           A. O. SCOTT             1  2017-11-16 17:44:38
# 1        MANOHLA DARGIS             1  2017-11-16 15:56:03
# 2           GLENN KENNY             1  2017-11-16 17:44:37
# 3           GLENN KENNY             1  2017-11-16 17:44:35
# 4   JEANNETTE CATSOULIS             1  2017-11-16 12:04:04
# 5            TEO BUGBEE             0  2017-11-16 12:04:02
# 6           A. O. SCOTT             0  2017-11-16 12:04:06
# 7   JEANNETTE CATSOULIS             0  2017-11-16 12:04:06
# 8           GLENN KENNY             0  2017-11-16 12:04:03
# 9        BEN KENIGSBERG             0  2017-11-16 17:44:34
# 10       BEN KENIGSBERG             0  2017-11-16 17:44:34
# 11          A. O. SCOTT             1  2017-11-15 20:38:02
# 12  JEANNETTE CATSOULIS             0  2017-11-15 17:36:03
# 13       MANOHLA DARGIS             0  2017-11-16 17:44:32
# 14       BEN KENIGSBERG             0  2017-11-16 17:44:32
# 15      MONICA CASTILLO             1  2017-11-16 17:44:30
# 16         ANDY WEBSTER             1  2017-11-09 12:04:03
# 17  JEANNETTE CATSOULIS             1  2017-11-16 17:44:28
# 18           TEO BUGBEE             1  2017-11-16 17:44:27
# 19       BEN KENIGSBERG             0  2017-11-16 17:44:31
#
#                                         display_title  \
# 0                                            Mudbound
# 1   Jim & Andy: The Great Beyond - Featuring a Ver...
# 2                                     The Breadwinner
# 3                                              Wonder
# 4                                      Sweet Virginia
# 5                                           Big Sonia
# 6                         On the Beach at Night Alone
# 7                                               Porto
# 8                               Wet Woman in the Wind
# 9                               Roman J. Israel, Esq.
# 10                                          Cook Off!
# 11                                  A Fantastic Woman
# 12                                   Rebels on Pointe
# 13                                     Justice League
# 14                                    Song of Granite
# 15                                     Santa & Andrés
# 16                                     I Remember You
# 17                                              Bitch
# 18  Window Horses: The Poetic Persian Epiphany of ...
# 19                                     Daddy's Home 2
#
#                                              headline  \
# 0   Review: ‘Mudbound’ Is a Racial Epic Tuned to B...
# 1    Review: ‘Jim & Andy,’ When Carrey Became Kaufman
# 2   Review: In ‘The Breadwinner,’ a Girl Bravely P...
# 3   Review: In ‘Wonder,’ a Not-So-Ordinary Boy Mak...
# 4   Review: A Small-Town Murder Ignites ‘Sweet Vir...
# 5     Review: ‘Big Sonia’ Honors a Holocaust Survivor
# 6   Review: ‘On the Beach at Night Alone’ Zooms in...
# 7   Review: In ‘Porto,’ a Night of Bliss and Heart...
# 8   Review: ‘Wet Woman in the Wind’ Is a Queasy Se...
# 9   Review: In ‘Roman J. Israel, Esq.,’ Denzel Was...
# 10  Review: ‘Cook Off!’ Gives Chefs the ‘Best in S...
# 11  Review: ‘A Fantastic Woman’ Lives Up to Its Ti...
# 12           Review: ‘Rebels on Pointe,’ and in Tutus
# 13  Review: ‘Justice League,’ Better Than the Last...
# 14  Review: In ‘Song of Granite,’ Fragments of an ...
# 15  Review: ‘Santa & Andrés’ Chooses Friendship Ov...
# 16  Review: ‘I Remember You’ Is a Piercing Horror ...
# 17  Review: In ‘Bitch,’ a Desperate Housewife Find...
# 18  Review: ‘Window Horses’ Animates a Young Poet’...
# 19  Review: In ‘Daddy’s Home 2,’ Father Doesn’t Kn...
#
#                              link.suggested_link_text link.type  \
# 0          Read the New York Times Review of Mudbound   article
# 1   Read the New York Times Review of Jim & Andy: ...   article
# 2   Read the New York Times Review of The Breadwinner   article
# 3            Read the New York Times Review of Wonder   article
# 4    Read the New York Times Review of Sweet Virginia   article
# 5         Read the New York Times Review of Big Sonia   article
# 6   Read the New York Times Review of On the Beach...   article
# 7             Read the New York Times Review of Porto   article
# 8   Read the New York Times Review of Wet Woman in...   article
# 9   Read the New York Times Review of Roman J. Isr...   article
# 10        Read the New York Times Review of Cook Off!   article
# 11  Read the New York Times Review of A Fantastic ...   article
# 12  Read the New York Times Review of Rebels on Po...   article
# 13   Read the New York Times Review of Justice League   article
# 14  Read the New York Times Review of Song of Granite   article
# 15   Read the New York Times Review of Santa & Andrés   article
# 16   Read the New York Times Review of I Remember You   article
# 17            Read the New York Times Review of Bitch   article
# 18  Read the New York Times Review of Window Horse...   article
# 19   Read the New York Times Review of Daddy's Home 2   article
#
#                                              link.url mpaa_rating  \
# 0   http://www.nytimes.com/2017/11/16/movies/mudbo...           R
# 1   http://www.nytimes.com/2017/11/16/movies/revie...
# 2   http://www.nytimes.com/2017/11/16/movies/the-b...       PG-13
# 3   http://www.nytimes.com/2017/11/16/movies/wonde...          PG
# 4   http://www.nytimes.com/2017/11/16/movies/sweet...           R
# 5   http://www.nytimes.com/2017/11/16/movies/revie...
# 6   http://www.nytimes.com/2017/11/16/movies/on-th...
# 7   http://www.nytimes.com/2017/11/16/movies/porto...
# 8   http://www.nytimes.com/2017/11/16/movies/wet-w...
# 9   http://www.nytimes.com/2017/11/16/movies/roman...       PG-13
# 10  http://www.nytimes.com/2017/11/16/movies/revie...           R
# 11  http://www.nytimes.com/2017/11/15/movies/a-fan...           R
# 12  http://www.nytimes.com/2017/11/15/movies/rebel...
# 13  http://www.nytimes.com/2017/11/15/movies/justi...       PG-13
# 14  http://www.nytimes.com/2017/11/14/movies/song-...
# 15  http://www.nytimes.com/2017/11/09/movies/santa...
# 16  http://www.nytimes.com/2017/11/09/movies/i-rem...
# 17  http://www.nytimes.com/2017/11/09/movies/bitch...
# 18  http://www.nytimes.com/2017/11/09/movies/windo...
# 19  http://www.nytimes.com/2017/11/09/movies/revie...       PG-13
#
#     multimedia.height                                     multimedia.src  \
# 0                 140  https://static01.nyt.com/images/2017/11/17/art...
# 1                 140  https://static01.nyt.com/images/2017/11/17/art...
# 2                 140  https://static01.nyt.com/images/2017/11/17/art...
# 3                 140  https://static01.nyt.com/images/2017/11/13/mov...
# 4                 140  https://static01.nyt.com/images/2017/11/15/mov...
# 5                 140  https://static01.nyt.com/images/2017/11/15/mov...
# 6                 140  https://static01.nyt.com/images/2017/11/17/art...
# 7                 140  https://static01.nyt.com/images/2017/11/17/art...
# 8                 140  https://static01.nyt.com/images/2017/11/17/mov...
# 9                 140  https://static01.nyt.com/images/2017/11/17/art...
# 10                140  https://static01.nyt.com/images/2017/11/15/art...
# 11                140  https://static01.nyt.com/images/2017/11/17/art...
# 12                140  https://static01.nyt.com/images/2017/11/15/art...
# 13                140  https://static01.nyt.com/images/2017/11/17/art...
# 14                140  https://static01.nyt.com/images/2017/11/15/art...
# 15                140  https://static01.nyt.com/images/2017/11/10/art...
# 16                140  https://static01.nyt.com/images/2017/11/10/mov...
# 17                140  https://static01.nyt.com/images/2017/11/08/art...
# 18                140  https://static01.nyt.com/images/2017/11/10/art...
# 19                140  https://static01.nyt.com/images/2017/11/10/art...
#
#         multimedia.type  multimedia.width opening_date publication_date  \
# 0   mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 1   mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 2   mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 3   mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 4   mediumThreeByTwo210               210         None       2017-11-16
# 5   mediumThreeByTwo210               210         None       2017-11-16
# 6   mediumThreeByTwo210               210         None       2017-11-16
# 7   mediumThreeByTwo210               210         None       2017-11-16
# 8   mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 9   mediumThreeByTwo210               210   2017-11-22       2017-11-16
# 10  mediumThreeByTwo210               210   2017-11-17       2017-11-16
# 11  mediumThreeByTwo210               210   2018-02-02       2017-11-15
# 12  mediumThreeByTwo210               210   2017-09-15       2017-11-15
# 13  mediumThreeByTwo210               210   2017-11-17       2017-11-15
# 14  mediumThreeByTwo210               210   2017-11-15       2017-11-14
# 15  mediumThreeByTwo210               210         None       2017-11-09
# 16  mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 17  mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 18  mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 19  mediumThreeByTwo210               210   2017-11-10       2017-11-09
#
#                                         summary_short
# 0   Dee Rees’s new film illuminates the daily crue...
# 1   In his documentary about Jim Carrey, Andy Kauf...
# 2   The children in this animated film based on a ...
# 3   Auggie, the little boy in this smart and warmh...
# 4   Set in a remote Alaskan valley, the film is a ...
# 5   Sonia Warshawski, the owner of a tailor shop i...
# 6   Kim Min-hee stars in a new film from the proli...
# 7   In one of the last film roles before his death...
# 8   Let’s make no bones about it: This film, part ...
# 9   Dan Gilroy’s new film about a socially awkward...
# 10  This mockumentary about a cooking competition ...
# 11  Facing a lover’s death and a society’s intoler...
# 12  The Ballets Russes de Monte Carlo meld techniq...
# 13  In this superhero jamboree, the Flash, Aquaman...
# 14  This biography of the singer Joe Heaney seems ...
# 15  A loyal Communist worker and a dissident gay w...
# 16  The director Oskar Thor Axelsson prefers mood ...
# 17  Jason Ritter plays a husband whose wife goes t...
# 18  Ann Marie Fleming’s film explores the passions...
# 19  Mel Gibson gets off lightly as a crass paterfa...

# %% [markdown]
# <h><b> Now we can display the data by three columns (byline, display_title, & summary_short). This will allow viewers to see the reviews easier. </b></h>

# %%
df = normal[['byline', 'display_title', 'summary_short']]
df
# Out:
#                  byline                                      display_title  \
# 0           A. O. SCOTT                                           Mudbound
# 1        MANOHLA DARGIS  Jim & Andy: The Great Beyond - Featuring a Ver...
# 2           GLENN KENNY                                    The Breadwinner
# 3           GLENN KENNY                                             Wonder
# 4   JEANNETTE CATSOULIS                                     Sweet Virginia
# 5            TEO BUGBEE                                          Big Sonia
# 6           A. O. SCOTT                        On the Beach at Night Alone
# 7   JEANNETTE CATSOULIS                                              Porto
# 8           GLENN KENNY                              Wet Woman in the Wind
# 9        BEN KENIGSBERG                              Roman J. Israel, Esq.
# 10       BEN KENIGSBERG                                          Cook Off!
# 11          A. O. SCOTT                                  A Fantastic Woman
# 12  JEANNETTE CATSOULIS                                   Rebels on Pointe
# 13       MANOHLA DARGIS                                     Justice League
# 14       BEN KENIGSBERG                                    Song of Granite
# 15      MONICA CASTILLO                                     Santa & Andrés
# 16         ANDY WEBSTER                                     I Remember You
# 17  JEANNETTE CATSOULIS                                              Bitch
# 18           TEO BUGBEE  Window Horses: The Poetic Persian Epiphany of ...
# 19       BEN KENIGSBERG                                     Daddy's Home 2
#
#                                         summary_short
# 0   Dee Rees’s new film illuminates the daily crue...
# 1   In his documentary about Jim Carrey, Andy Kauf...
# 2   The children in this animated film based on a ...
# 3   Auggie, the little boy in this smart and warmh...
# 4   Set in a remote Alaskan valley, the film is a ...
# 5   Sonia Warshawski, the owner of a tailor shop i...
# 6   Kim Min-hee stars in a new film from the proli...
# 7   In one of the last film roles before his death...
# 8   Let’s make no bones about it: This film, part ...
# 9   Dan Gilroy’s new film about a socially awkward...
# 10  This mockumentary about a cooking competition ...
# 11  Facing a lover’s death and a society’s intoler...
# 12  The Ballets Russes de Monte Carlo meld techniq...
# 13  In this superhero jamboree, the Flash, Aquaman...
# 14  This biography of the singer Joe Heaney seems ...
# 15  A loyal Communist worker and a dissident gay w...
# 16  The director Oskar Thor Axelsson prefers mood ...
# 17  Jason Ritter plays a husband whose wife goes t...
# 18  Ann Marie Fleming’s film explores the passions...
# 19  Mel Gibson gets off lightly as a crass paterfa...

# %% [markdown]
# <div align='center'> <b> <span style='color:green'> <h1> THANK YOU </h1> </span> </b> </div>
