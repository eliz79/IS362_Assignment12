# %% [markdown]
# <div align='center'> <b> <span style='color:green'> <h1> ASSIGNMENT WEEK 13 - PREDICTIVE ANALYSIS </h1> </span> </b> </div>

# %% [markdown]
# The New York Times web site provides a rich set of [APIs](http://developer.nytimes.com/docs).
#
# For this assignment, you’ll need to start by signing up for an API [key](http://developer.nytimes.com/signup). Your task is to choose one of the New York Times APIs, construct an interface in [Python](https://www.python.org/) to read in the [JSON](https://www.json.org/) data, and transform it into a [pandas](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) DataFrame.

# %% [markdown]
# <h><b> We begin by importing the necessary libraries. </b></h>

# %%
import pandas as pd
import json, requests
from pandas.io.json import json_normalize

# %% [markdown]
# <h><b> We proceed by requesting the API data. </b></h>

# %%
#The data is obtained from - http://developer.nytimes.com/movie_reviews_v2.json#/Console/GET/reviews/search.json
#Once signed up NYT provides an API Key: '9e5f80aa2fa343afa13d9389c62c852b'

api_key = '9e5f80aa2fa343afa13d9389c62c852b'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
string = url + '&api-key=' + api_key

repos = json.loads(requests.get(string).text) #getting data to display
repos
# Out:
# {'copyright': 'Copyright (c) 2017 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'byline': 'A. O. SCOTT',
#    'critics_pick': 1,
#    'date_updated': '2017-11-15 20:38:02',
#    'display_title': 'A Fantastic Woman',
#    'headline': 'Review: ‘A Fantastic Woman’ Lives Up to Its Title, in More Ways Than One',
#    'link': {'suggested_link_text': 'Read the New York Times Review of A Fantastic Woman',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/a-fantastic-woman-review.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17fantastic1/17fantastic1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2018-02-02',
#    'publication_date': '2017-11-15',
#    'summary_short': 'Facing a lover’s death and a society’s intolerance, in a film by Sebastián Lelio.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:36:03',
#    'display_title': 'Rebels on Pointe',
#    'headline': 'Review: ‘Rebels on Pointe,’ and in Tutus',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Rebels on Pointe',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/rebels-on-pointe-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/arts/17REBELS1/17REBELS1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-09-15',
#    'publication_date': '2017-11-15',
#    'summary_short': 'The Ballets Russes de Monte Carlo meld technique with comedy, and tour more than two-thirds of the years'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:33',
#    'display_title': 'Justice League',
#    'headline': 'Review: ‘Justice League,’ Better Than the Last One!',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Justice League',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/15/movies/justice-league-review-wonder-woman-batman-dc-comics.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/17/arts/17justiceleague-web1/17justiceleague-web1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-17',
#    'publication_date': '2017-11-15',
#    'summary_short': 'In this superhero jamboree, the Flash, Aquaman and Cyborg sign on with the DC Comics team leaders Batman and Wonder Woman. (Psst … where’s Superman?)'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:33',
#    'display_title': 'Song of Granite',
#    'headline': 'Review: In ‘Song of Granite,’ Fragments of an Irish Folk Singer’s Life',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Song of Granite',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/14/movies/song-of-granite-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/15/arts/15SONGOFGRANITE/15SONGOFGRANITE-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-15',
#    'publication_date': '2017-11-14',
#    'summary_short': 'This biography of the singer Joe Heaney seems uncertain of what made him tick.'},
#   {'byline': 'MONICA CASTILLO',
#    'critics_pick': 1,
#    'date_updated': '2017-11-15 17:44:31',
#    'display_title': 'Santa & Andrés',
#    'headline': 'Review: ‘Santa & Andrés’ Chooses Friendship Over Politics',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Santa & Andrés',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/santa-and-andres-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10SANTAANDRES/santa1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'A loyal Communist worker and a dissident gay writer become unlikely friends in this touching Cuban drama.'},
#   {'byline': 'ANDY WEBSTER',
#    'critics_pick': 1,
#    'date_updated': '2017-11-09 12:04:03',
#    'display_title': 'I Remember You',
#    'headline': 'Review: ‘I Remember You’ Is a Piercing Horror Film From Iceland',
#    'link': {'suggested_link_text': 'Read the New York Times Review of I Remember You',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/i-remember-you-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/movies/10irememberyou/10irememberyou-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'The director Oskar Thor Axelsson prefers mood and compelling human conflict over copious gore to deliver chills. The result is effective.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 1,
#    'date_updated': '2017-11-15 17:44:29',
#    'display_title': 'Bitch',
#    'headline': 'Review: In ‘Bitch,’ a Desperate Housewife Finds Her Bark',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Bitch',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/bitch-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/08/arts/bitch1/bitch1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Jason Ritter plays a husband whose wife goes to the dogs in this feminist horror-comedy.'},
#   {'byline': 'TEO BUGBEE',
#    'critics_pick': 1,
#    'date_updated': '2017-11-15 17:44:27',
#    'display_title': 'Window Horses: The Poetic Persian Epiphany of Rosie Ming',
#    'headline': 'Review: ‘Window Horses’ Animates a Young Poet’s Self-Discovery',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Window Horses: The Poetic Persian Epiphany of Rosie Ming',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/window-horses-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10windowhorses/windowhorses1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Ann Marie Fleming’s film explores the passions of a sheltered poet who travels to Shiraz, Iran, for a poetry festival.'},
#   {'byline': 'BEN KENIGSBERG',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:32',
#    'display_title': "Daddy's Home 2",
#    'headline': 'Review: In ‘Daddy’s Home 2,’ Father Doesn’t Know Best',
#    'link': {'suggested_link_text': "Read the New York Times Review of Daddy's Home 2",
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/review-in-daddys-home-2-mel-gibson-will-ferrell-mark-wahlberg.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10daddyshome1/10daddyshome1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'Mel Gibson gets off lightly as a crass paterfamilias in this comedy sequel to the hit starring Will Ferrell and Mark Wahlberg.'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:32',
#    'display_title': 'Thelma',
#    'headline': 'Review: In ‘Thelma,’ a Woman in Love Can Burn Down the World',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Thelma',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/review-in-thelma-a-woman-in-love-can-burn-down-the-world.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10thelma-web/10thelma-web-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'In Joachim Trier’s sly psychological thriller “Thelma,” a child-woman finds love and discovers that behaving like a good girl can be a very bad idea.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-09 12:04:03',
#    'display_title': 'Flesh and Blood',
#    'headline': 'Review: Reality Bites in ‘Flesh and Blood’',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Flesh and Blood',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/flesh-and-blood-review-mark-webber.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10fleshandblood/10fleshandblood-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'The actor and director Mark Webber portrays a former addict newly released from prison and returning home to reconnect with family.'},
#   {'byline': 'KEN JAWOROWSKI',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:30',
#    'display_title': 'Intent to Destroy',
#    'headline': 'Review: ‘Intent to Destroy’ Shows That the Armenian Past Is Not Over',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Intent to Destroy',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/intent-to-destroy-armenian-genocide-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/movies/10intenttodestroy2/10intenttodestroy2-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': 'This documentary, directed by Joe Berlinger, explores the Armenian genocide through old footage of survivors and insights from historians.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:02',
#    'display_title': 'No Stone Unturned',
#    'headline': 'Review: ‘No Stone Unturned’ Explores an Attack in Northern Ireland',
#    'link': {'suggested_link_text': 'Read the New York Times Review of No Stone Unturned',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/no-stone-unturned-review-alex-gibney-northern-ireland.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/04/arts/NOSTONE1/NOSTONE1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'Why did a massacre in a Northern Ireland pub go unsolved for 20 years? The documentary filmmaker Alex Gibney searches for answers.'},
#   {'byline': 'JEANNETTE CATSOULIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:28',
#    'display_title': 'Mayhem',
#    'headline': 'Review: A Virus Creates ‘Mayhem’ Among Backstabbing Lawyers',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Mayhem',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/mayhem-review-steven-yeun.html'},
#    'mpaa_rating': 'Not Rated',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/09/arts/MAYHEM1/MAYHEM1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-09',
#    'summary_short': '“Mayhem,” featuring the “Walking Dead” actor Steven Yeun, embraces its pulpy title with fighting-and-fornicating glee.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:28',
#    'display_title': 'Destination Unknown',
#    'headline': 'Review: ‘Destination Unknown,’ Nazi Camps Through the Eyes of Survivors',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Destination Unknown',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/09/movies/destination-unknown-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/03/arts/destination2/destination2-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': None,
#    'publication_date': '2017-11-09',
#    'summary_short': 'Horror, sadness and a note of hope characterize the stories of 12 people who lived through the Nazi camps.'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:27',
#    'display_title': 'Three Billboards Outside Ebbing, Missouri',
#    'headline': 'Review: On Violence and the Pain of Others in ‘Three Billboards’',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Three Billboards Outside Ebbing, Missouri',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/08/movies/review-three-billboards-outside-ebbing-missouri-martin-mcdonagh.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10threebillboards1/10threebillboards-web-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-08',
#    'summary_short': 'A ferocious Frances McDormand plays a grieving mother seeking justice in Martin McDonagh’s movie, which mixes tears and tragedy with corrosive laughs.'},
#   {'byline': 'GLENN KENNY',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:26',
#    'display_title': 'Murder on the Orient Express',
#    'headline': 'Review: An All-Star ‘Murder on the Orient Express’ With Few Surprises',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Murder on the Orient Express',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/08/movies/murder-on-the-orient-express-review-kenneth-branagh.html'},
#    'mpaa_rating': 'PG-13',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/10/arts/10murderontheorient1/10murderontheorient1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-10',
#    'publication_date': '2017-11-08',
#    'summary_short': 'Kenneth Branagh assembles Judi Dench, Johnny Depp, Michelle Pfeiffer and others for his film remake of Agatha Christie’s mystery novel.'},
#   {'byline': 'ANDY WEBSTER',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:26',
#    'display_title': 'Hello Again',
#    'headline': 'Review: ‘Hello Again,’ a Movie Musical Ode to Love and Lust Over Decades',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Hello Again',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/07/movies/hello-again-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/08/arts/08HELLOAGAIN/08HELLOAGAIN-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-08',
#    'publication_date': '2017-11-07',
#    'summary_short': 'This film from Tom Gustafson, based on a 1993 Off Broadway show, has a formidable cast of Broadway names but wants for dramatic traction.'},
#   {'byline': 'ANDY WEBSTER',
#    'critics_pick': 1,
#    'date_updated': '2017-11-10 17:44:01',
#    'display_title': 'Most Beautiful Island',
#    'headline': 'Review: ‘Most Beautiful Island,’ an Immigrant’s New York Nightmare',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Most Beautiful Island',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/02/movies/most-beautiful-island-review.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/10/31/arts/MOSTBEAUTIFUL1/MOSTBEAUTIFUL1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-03',
#    'publication_date': '2017-11-02',
#    'summary_short': 'This suspense film, about a woman entering a rabbit hole of urban peril, is an effective writing-directing debut for Ana Asensio, who also stars.'},
#   {'byline': 'MANOHLA DARGIS',
#    'critics_pick': 0,
#    'date_updated': '2017-11-15 17:44:25',
#    'display_title': 'LBJ',
#    'headline': 'Review: ‘LBJ’ Hides Its Light Under a Bushel of Makeup',
#    'link': {'suggested_link_text': 'Read the New York Times Review of LBJ',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2017/11/02/movies/lbj-review-woody-harrelson-rob-reiner.html'},
#    'mpaa_rating': 'R',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2017/11/03/arts/03lbj-web1/03lbj-web1-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2017-11-03',
#    'publication_date': '2017-11-02',
#    'summary_short': 'Woody Harrelson swaggers through this movie, which tries to track the coming into consciousness of Lyndon B. Johnson.'}],
#  'status': 'OK'}

# %% [markdown]
# <h><b> For easier viewing we can proceed by normalizing the data. </b></h>

# %%
normal = json_normalize(repos['results'])
normal
# Out:
#                  byline  critics_pick         date_updated  \
# 0           A. O. SCOTT             1  2017-11-15 20:38:02
# 1   JEANNETTE CATSOULIS             0  2017-11-15 17:36:03
# 2        MANOHLA DARGIS             0  2017-11-15 17:44:33
# 3        BEN KENIGSBERG             0  2017-11-15 17:44:33
# 4       MONICA CASTILLO             1  2017-11-15 17:44:31
# 5          ANDY WEBSTER             1  2017-11-09 12:04:03
# 6   JEANNETTE CATSOULIS             1  2017-11-15 17:44:29
# 7            TEO BUGBEE             1  2017-11-15 17:44:27
# 8        BEN KENIGSBERG             0  2017-11-15 17:44:32
# 9        MANOHLA DARGIS             0  2017-11-15 17:44:32
# 10  JEANNETTE CATSOULIS             0  2017-11-09 12:04:03
# 11       KEN JAWOROWSKI             0  2017-11-15 17:44:30
# 12          GLENN KENNY             0  2017-11-15 17:44:02
# 13  JEANNETTE CATSOULIS             0  2017-11-15 17:44:28
# 14          GLENN KENNY             0  2017-11-15 17:44:28
# 15       MANOHLA DARGIS             0  2017-11-15 17:44:27
# 16          GLENN KENNY             0  2017-11-15 17:44:26
# 17         ANDY WEBSTER             0  2017-11-15 17:44:26
# 18         ANDY WEBSTER             1  2017-11-10 17:44:01
# 19       MANOHLA DARGIS             0  2017-11-15 17:44:25
#
#                                         display_title  \
# 0                                   A Fantastic Woman
# 1                                    Rebels on Pointe
# 2                                      Justice League
# 3                                     Song of Granite
# 4                                      Santa & Andrés
# 5                                      I Remember You
# 6                                               Bitch
# 7   Window Horses: The Poetic Persian Epiphany of ...
# 8                                      Daddy's Home 2
# 9                                              Thelma
# 10                                    Flesh and Blood
# 11                                  Intent to Destroy
# 12                                  No Stone Unturned
# 13                                             Mayhem
# 14                                Destination Unknown
# 15          Three Billboards Outside Ebbing, Missouri
# 16                       Murder on the Orient Express
# 17                                        Hello Again
# 18                              Most Beautiful Island
# 19                                                LBJ
#
#                                              headline  \
# 0   Review: ‘A Fantastic Woman’ Lives Up to Its Ti...
# 1            Review: ‘Rebels on Pointe,’ and in Tutus
# 2   Review: ‘Justice League,’ Better Than the Last...
# 3   Review: In ‘Song of Granite,’ Fragments of an ...
# 4   Review: ‘Santa & Andrés’ Chooses Friendship Ov...
# 5   Review: ‘I Remember You’ Is a Piercing Horror ...
# 6   Review: In ‘Bitch,’ a Desperate Housewife Find...
# 7   Review: ‘Window Horses’ Animates a Young Poet’...
# 8   Review: In ‘Daddy’s Home 2,’ Father Doesn’t Kn...
# 9   Review: In ‘Thelma,’ a Woman in Love Can Burn ...
# 10         Review: Reality Bites in ‘Flesh and Blood’
# 11  Review: ‘Intent to Destroy’ Shows That the Arm...
# 12  Review: ‘No Stone Unturned’ Explores an Attack...
# 13  Review: A Virus Creates ‘Mayhem’ Among Backsta...
# 14  Review: ‘Destination Unknown,’ Nazi Camps Thro...
# 15  Review: On Violence and the Pain of Others in ...
# 16  Review: An All-Star ‘Murder on the Orient Expr...
# 17  Review: ‘Hello Again,’ a Movie Musical Ode to ...
# 18  Review: ‘Most Beautiful Island,’ an Immigrant’...
# 19  Review: ‘LBJ’ Hides Its Light Under a Bushel o...
#
#                              link.suggested_link_text link.type  \
# 0   Read the New York Times Review of A Fantastic ...   article
# 1   Read the New York Times Review of Rebels on Po...   article
# 2    Read the New York Times Review of Justice League   article
# 3   Read the New York Times Review of Song of Granite   article
# 4    Read the New York Times Review of Santa & Andrés   article
# 5    Read the New York Times Review of I Remember You   article
# 6             Read the New York Times Review of Bitch   article
# 7   Read the New York Times Review of Window Horse...   article
# 8    Read the New York Times Review of Daddy's Home 2   article
# 9            Read the New York Times Review of Thelma   article
# 10  Read the New York Times Review of Flesh and Blood   article
# 11  Read the New York Times Review of Intent to De...   article
# 12  Read the New York Times Review of No Stone Unt...   article
# 13           Read the New York Times Review of Mayhem   article
# 14  Read the New York Times Review of Destination ...   article
# 15  Read the New York Times Review of Three Billbo...   article
# 16  Read the New York Times Review of Murder on th...   article
# 17      Read the New York Times Review of Hello Again   article
# 18  Read the New York Times Review of Most Beautif...   article
# 19              Read the New York Times Review of LBJ   article
#
#                                              link.url mpaa_rating  \
# 0   http://www.nytimes.com/2017/11/15/movies/a-fan...           R
# 1   http://www.nytimes.com/2017/11/15/movies/rebel...
# 2   http://www.nytimes.com/2017/11/15/movies/justi...       PG-13
# 3   http://www.nytimes.com/2017/11/14/movies/song-...
# 4   http://www.nytimes.com/2017/11/09/movies/santa...
# 5   http://www.nytimes.com/2017/11/09/movies/i-rem...
# 6   http://www.nytimes.com/2017/11/09/movies/bitch...
# 7   http://www.nytimes.com/2017/11/09/movies/windo...
# 8   http://www.nytimes.com/2017/11/09/movies/revie...       PG-13
# 9   http://www.nytimes.com/2017/11/09/movies/revie...
# 10  http://www.nytimes.com/2017/11/09/movies/flesh...
# 11  http://www.nytimes.com/2017/11/09/movies/inten...
# 12  http://www.nytimes.com/2017/11/09/movies/no-st...
# 13  http://www.nytimes.com/2017/11/09/movies/mayhe...   Not Rated
# 14  http://www.nytimes.com/2017/11/09/movies/desti...
# 15  http://www.nytimes.com/2017/11/08/movies/revie...           R
# 16  http://www.nytimes.com/2017/11/08/movies/murde...       PG-13
# 17  http://www.nytimes.com/2017/11/07/movies/hello...
# 18  http://www.nytimes.com/2017/11/02/movies/most-...
# 19  http://www.nytimes.com/2017/11/02/movies/lbj-r...           R
#
#     multimedia.height                                     multimedia.src  \
# 0                 140  https://static01.nyt.com/images/2017/11/17/art...
# 1                 140  https://static01.nyt.com/images/2017/11/15/art...
# 2                 140  https://static01.nyt.com/images/2017/11/17/art...
# 3                 140  https://static01.nyt.com/images/2017/11/15/art...
# 4                 140  https://static01.nyt.com/images/2017/11/10/art...
# 5                 140  https://static01.nyt.com/images/2017/11/10/mov...
# 6                 140  https://static01.nyt.com/images/2017/11/08/art...
# 7                 140  https://static01.nyt.com/images/2017/11/10/art...
# 8                 140  https://static01.nyt.com/images/2017/11/10/art...
# 9                 140  https://static01.nyt.com/images/2017/11/10/art...
# 10                140  https://static01.nyt.com/images/2017/11/10/art...
# 11                140  https://static01.nyt.com/images/2017/11/10/mov...
# 12                140  https://static01.nyt.com/images/2017/11/04/art...
# 13                140  https://static01.nyt.com/images/2017/11/09/art...
# 14                140  https://static01.nyt.com/images/2017/11/03/art...
# 15                140  https://static01.nyt.com/images/2017/11/10/art...
# 16                140  https://static01.nyt.com/images/2017/11/10/art...
# 17                140  https://static01.nyt.com/images/2017/11/08/art...
# 18                140  https://static01.nyt.com/images/2017/10/31/art...
# 19                140  https://static01.nyt.com/images/2017/11/03/art...
#
#         multimedia.type  multimedia.width opening_date publication_date  \
# 0   mediumThreeByTwo210               210   2018-02-02       2017-11-15
# 1   mediumThreeByTwo210               210   2017-09-15       2017-11-15
# 2   mediumThreeByTwo210               210   2017-11-17       2017-11-15
# 3   mediumThreeByTwo210               210   2017-11-15       2017-11-14
# 4   mediumThreeByTwo210               210         None       2017-11-09
# 5   mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 6   mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 7   mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 8   mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 9   mediumThreeByTwo210               210         None       2017-11-09
# 10  mediumThreeByTwo210               210         None       2017-11-09
# 11  mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 12  mediumThreeByTwo210               210         None       2017-11-09
# 13  mediumThreeByTwo210               210   2017-11-10       2017-11-09
# 14  mediumThreeByTwo210               210         None       2017-11-09
# 15  mediumThreeByTwo210               210   2017-11-10       2017-11-08
# 16  mediumThreeByTwo210               210   2017-11-10       2017-11-08
# 17  mediumThreeByTwo210               210   2017-11-08       2017-11-07
# 18  mediumThreeByTwo210               210   2017-11-03       2017-11-02
# 19  mediumThreeByTwo210               210   2017-11-03       2017-11-02
#
#                                         summary_short
# 0   Facing a lover’s death and a society’s intoler...
# 1   The Ballets Russes de Monte Carlo meld techniq...
# 2   In this superhero jamboree, the Flash, Aquaman...
# 3   This biography of the singer Joe Heaney seems ...
# 4   A loyal Communist worker and a dissident gay w...
# 5   The director Oskar Thor Axelsson prefers mood ...
# 6   Jason Ritter plays a husband whose wife goes t...
# 7   Ann Marie Fleming’s film explores the passions...
# 8   Mel Gibson gets off lightly as a crass paterfa...
# 9   In Joachim Trier’s sly psychological thriller ...
# 10  The actor and director Mark Webber portrays a ...
# 11  This documentary, directed by Joe Berlinger, e...
# 12  Why did a massacre in a Northern Ireland pub g...
# 13  “Mayhem,” featuring the “Walking Dead” actor S...
# 14  Horror, sadness and a note of hope characteriz...
# 15  A ferocious Frances McDormand plays a grieving...
# 16  Kenneth Branagh assembles Judi Dench, Johnny D...
# 17  This film from Tom Gustafson, based on a 1993 ...
# 18  This suspense film, about a woman entering a r...
# 19  Woody Harrelson swaggers through this movie, w...

# %% [markdown]
# <h><b> Now we can display the data by three columns (byline, display_title, & summary_short). This will allow viewers to see the reviews easier. </b></h>

# %%
df = normal[['byline', 'display_title', 'summary_short']]
df
# Out:
#                  byline                                      display_title  \
# 0           A. O. SCOTT                                  A Fantastic Woman
# 1   JEANNETTE CATSOULIS                                   Rebels on Pointe
# 2        MANOHLA DARGIS                                     Justice League
# 3        BEN KENIGSBERG                                    Song of Granite
# 4       MONICA CASTILLO                                     Santa & Andrés
# 5          ANDY WEBSTER                                     I Remember You
# 6   JEANNETTE CATSOULIS                                              Bitch
# 7            TEO BUGBEE  Window Horses: The Poetic Persian Epiphany of ...
# 8        BEN KENIGSBERG                                     Daddy's Home 2
# 9        MANOHLA DARGIS                                             Thelma
# 10  JEANNETTE CATSOULIS                                    Flesh and Blood
# 11       KEN JAWOROWSKI                                  Intent to Destroy
# 12          GLENN KENNY                                  No Stone Unturned
# 13  JEANNETTE CATSOULIS                                             Mayhem
# 14          GLENN KENNY                                Destination Unknown
# 15       MANOHLA DARGIS          Three Billboards Outside Ebbing, Missouri
# 16          GLENN KENNY                       Murder on the Orient Express
# 17         ANDY WEBSTER                                        Hello Again
# 18         ANDY WEBSTER                              Most Beautiful Island
# 19       MANOHLA DARGIS                                                LBJ
#
#                                         summary_short
# 0   Facing a lover’s death and a society’s intoler...
# 1   The Ballets Russes de Monte Carlo meld techniq...
# 2   In this superhero jamboree, the Flash, Aquaman...
# 3   This biography of the singer Joe Heaney seems ...
# 4   A loyal Communist worker and a dissident gay w...
# 5   The director Oskar Thor Axelsson prefers mood ...
# 6   Jason Ritter plays a husband whose wife goes t...
# 7   Ann Marie Fleming’s film explores the passions...
# 8   Mel Gibson gets off lightly as a crass paterfa...
# 9   In Joachim Trier’s sly psychological thriller ...
# 10  The actor and director Mark Webber portrays a ...
# 11  This documentary, directed by Joe Berlinger, e...
# 12  Why did a massacre in a Northern Ireland pub g...
# 13  “Mayhem,” featuring the “Walking Dead” actor S...
# 14  Horror, sadness and a note of hope characteriz...
# 15  A ferocious Frances McDormand plays a grieving...
# 16  Kenneth Branagh assembles Judi Dench, Johnny D...
# 17  This film from Tom Gustafson, based on a 1993 ...
# 18  This suspense film, about a woman entering a r...
# 19  Woody Harrelson swaggers through this movie, w...

# %% [markdown]
# <div align='center'> <b> <span style='color:green'> <h1> THANK YOU </h1> </span> </b> </div>
